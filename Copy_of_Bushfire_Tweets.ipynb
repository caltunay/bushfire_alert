# %% [markdown]
# <a href="https://colab.research.google.com/github/caltunay/bushfire_alert/blob/main/Copy_of_Bushfire_Tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Twint

# %%
pip install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /tmp/pip-install-pw69__br/twint
#   Running command git clone -q https://github.com/twintproject/twint.git /tmp/pip-install-pw69__br/twint
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# ...
#      |████████████████████████████████| 1.3MB 25.0MB/s
# ...
#      |████████████████████████████████| 266kB 33.9MB/s
# ...
#      |████████████████████████████████| 358kB 39.7MB/s
# ...
#      |████████████████████████████████| 296kB 39.5MB/s
# ...
#      |████████████████████████████████| 143kB 48.4MB/s
# ...
#      |████████████████████████████████| 296kB 43.1MB/s
# ...
#   Created wheel for twint: filename=twint-2.1.21-cp37-none-any.whl size=38872 sha256=287a6d9ff9a4584f2f88b50b56551ccb521d49fd017e30a051d935bb237ee30f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hakbeyi6/wheels/4f/3b/75/62d04b3b446658ba85401e8868d3cd1d4bc22f17ad755460a6
# ...

# %%
pip install nest_asyncio

# %%
import pandas as pd 
import numpy as npaiohttp

import nest_asyncio
nest_asyncio.apply()

import twint
import pandas

import time
import datetime

# %%
# extract tweets and create dataframe by list of keywords
# for australia
# post 2018
def scrape_keywords(*args):
    df = pd.DataFrame() # empty df to append tweets for each keyword within loop

    # twint config  
    c = twint.Config()
    
    c.Lang = "en"
    c.Near = 'Australia'
    c.Since = '2018-01-01'
    c.Hide_output = True
    # c.Store_csv = True
    c.Pandas = True
    
    # loop through keywords, extract tweets and append to df
    for keyword in args:
        
        c.Search = keyword
        twint.run.Search(c)
        df_temp = twint.storage.panda.Tweets_df # tweets df for keyword

        try:
            if len(df) == 0 and len(df_temp) != 0: 
                df_temp['keyword'] = keyword # add current keyword to dataframe
                df = df_temp.copy()
            elif len(df) != 0 and len(df_temp) != 0:
                df_temp['keyword'] = keyword # add current keyword to dataframe
                df = df.append(df_temp, ignore_index = True)
        except:
            pass

    dt_stamp = datetime.datetime.now()
    df.to_csv(f'tweets_df_{dt_stamp}.csv') # output all tweets to csv
    return df

# %%
aus_fire = scrape_keywords('firestorm', 'conflagration', 'fire', 'bushfire', 'wildfire', 'smoke')
aus_fire
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#                        id      conversation_id  ...  trans_dest        keyword
# 0     1400389478863171585  1400282574300192769  ...              conflagration
# 1     1399946458313347076  1399946458313347076  ...              conflagration
# 2     1402098802169810947  1402098802169810947  ...                       fire
# 3     1402098414406430739  1402098414406430739  ...                       fire
# 4     1402097366820261890  1402097366820261890  ...                       fire
# ...
